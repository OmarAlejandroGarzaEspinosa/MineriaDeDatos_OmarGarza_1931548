# %% [markdown]
# # P1-Manipulación de Datos

# %% [markdown]
# ## Librerias a utilizar

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Llamamos la base de datos

# %%
df = pd.read_csv("cardio_train.csv", sep=';')

# %% [markdown]
# ## Visualización de los datos

# %% [markdown]
# ### Primero checamos los datos que conforma nuestra base de datos

# %%
df.shape
# Out:
# (70000, 13)

# %% [markdown]
# ### Aquí checamos los primeros 5 renglones de nuestra base de datos

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# ### Aquí checamos los últimos 5 renglones de nuestra base de datos

# %%
df.tail()
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# 69995      1     0       1       0
# 69996      0     0       1       1
# 69997      0     1       0       1
# 69998      0     0       0       1
# 69999      0     0       1       0

# %% [markdown]
# ### Aquí checamos que tipo de datos tiene cada columna

# %%
df.dtypes
# Out:
# id               int64
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %% [markdown]
# ### Aquí borramos la columna de id ya que no la ocupamos

# %%
dfn = df.drop("id",axis=1)

# %% [markdown]
# ### Imprimimos la tabla ya corregida

# %%
dfn
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %% [markdown]
# ### Aquí revisamos si existen datos nulos en nuestra base de datos

# %%
dfn.isnull()
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol   gluc  smoke  \
# 0      False   False   False   False  False  False        False  False  False
# 1      False   False   False   False  False  False        False  False  False
# 2      False   False   False   False  False  False        False  False  False
# 3      False   False   False   False  False  False        False  False  False
# 4      False   False   False   False  False  False        False  False  False
# ...      ...     ...     ...     ...    ...    ...          ...    ...    ...
# 69995  False   False   False   False  False  False        False  False  False
# 69996  False   False   False   False  False  False        False  False  False
# 69997  False   False   False   False  False  False        False  False  False
# 69998  False   False   False   False  False  False        False  False  False
# 69999  False   False   False   False  False  False        False  False  False
#
#         alco  active  cardio
# ...

# %%
dfn.isnull().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %% [markdown]
# ### Aquí dice que no se encuentran datos nulos en ninguna columna

# %% [markdown]
# ## Vamos a cambiar la columna peso de flotante a entero

# %%
dfn['weight'] = dfn['weight'].astype('int64')

# %%
dfn.dtypes
# Out:
# age            int64
# gender         int64
# height         int64
# weight         int64
# ap_hi          int64
# ap_lo          int64
# cholesterol    int64
# gluc           int64
# smoke          int64
# alco           int64
# active         int64
# cardio         int64
# dtype: object

# %%
dfn.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  18393       2     168      62    110     80            1     1      0
# 1  20228       1     156      85    140     90            3     1      0
# 2  18857       1     165      64    130     70            3     1      0
# 3  17623       2     169      82    150    100            1     1      0
# 4  17474       1     156      56    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
dfn.columns
# Out:
# Index(['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol',
#        'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %% [markdown]
# ## Vamos a cambiar el nombre de 2 columnas

# %%
dfn.rename(columns = {'ap_hi':'sistolic'}).rename(columns = {'ap_lo':'diastolic'})
# Out:
#          age  gender  height  weight  sistolic  diastolic  cholesterol  gluc  \
# 0      18393       2     168      62       110         80            1     1
# 1      20228       1     156      85       140         90            3     1
# 2      18857       1     165      64       130         70            3     1
# 3      17623       2     169      82       150        100            1     1
# 4      17474       1     156      56       100         60            1     1
# ...      ...     ...     ...     ...       ...        ...          ...   ...
# 69995  19240       2     168      76       120         80            1     1
# 69996  22601       1     158     126       140         90            2     2
# 69997  19066       2     183     105       180         90            3     1
# 69998  22431       1     163      72       135         80            1     2
# 69999  20540       1     170      72       120         80            2     1
#
#        smoke  alco  active  cardio
# ...
